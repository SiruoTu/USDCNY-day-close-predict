# %%
import os
import pandas as pd

# 获取当前工作目录
cwd = os.getcwd()

# 指定要读取数据的目录
data_dir = os.path.join(cwd, 'data_xlsx')

# 指定输出目录
output_dir = os.path.join(cwd, 'data_csv')

# 如果输出目录不存在，则创建它
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# 指定要读取数据的文件名
data_file = '即期汇率_美元兑人民币.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
# 指定输出文件名
output_file = '即期汇率_美元兑人民币.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = 'USDCNH_即期汇率.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
# 指定输出文件名
output_file = 'USDCNH_即期汇率.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

#data_file = '000300.SH-行情统计-20230712.xlsx'
#data_path = os.path.join(data_dir, data_file)
#df = pd.read_excel(data_path)
#df = df.dropna()
#df['交易日期'] = pd.to_datetime(df['交易日期'])
#output_file = '000300.SH-行情统计.csv'
#output_path = os.path.join(output_dir, output_file)
#df.to_csv(output_path, index = None, header = True)

#data_file = 'SPX.GI-行情统计-20230712.xlsx'
#data_path = os.path.join(data_dir, data_file)
#df = pd.read_excel(data_path)
#df = df.dropna()
#df['交易日期'] = pd.to_datetime(df['交易日期'])
#output_file = 'SPX.GI-行情统计.csv'
#output_path = os.path.join(output_dir, output_file)
#df.to_csv(output_path, index = None, header = True)

data_file = '沪深300指数.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '沪深300指数.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = '美国_标准普尔500指数.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '美国_标准普尔500指数.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = '深证成份指数.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '深证成份指数.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = '美国_纳斯达克综合指数.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '美国_纳斯达克综合指数.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = '上证综合指数.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '上证综合指数.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = '美国_道琼斯工业平均指数.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '美国_道琼斯工业平均指数.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = '美元指数.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '美元指数.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = '美国_国债收益率_10年.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '美国_国债收益率_10年.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = '美国_国债收益率_2年.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '美国_国债收益率_2年.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = '现货价_原油_美国西德克萨斯中级轻质原油(WTI).xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '现货价_原油_美国西德克萨斯中级轻质原油(WTI).csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = '现货价_原油_英国布伦特Dtd.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '现货价_原油_英国布伦特Dtd.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = '现货价_原油(中国胜利)_环太平洋.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '现货价_原油(中国胜利)_环太平洋.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = '现货价_原油(中国大庆)_环太平洋.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '现货价_原油(中国大庆)_环太平洋.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = '伦敦现货黄金_以美元计价.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '伦敦现货黄金_以美元计价.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = '基础金价_中国黄金.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '基础金价_中国黄金.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

#data_file = '期货收盘价(活跃合约)_COMEX黄金.xlsx'
#data_path = os.path.join(data_dir, data_file)
#df = pd.read_excel(data_path).dropna()
#df['指标名称'] = pd.to_datetime(df['指标名称'])
#output_file = '期货收盘价(活跃合约)_COMEX黄金.csv'
#output_path = os.path.join(output_dir, output_file)
#df.to_csv(output_path, index = None, header = True)

#data_file = '期货收盘价(活跃合约)_黄金.xlsx'
#data_path = os.path.join(data_dir, data_file)
#df = pd.read_excel(data_path).dropna()
#df['指标名称'] = pd.to_datetime(df['指标名称'])
#output_file = '期货收盘价(活跃合约)_黄金.csv'
#output_path = os.path.join(output_dir, output_file)
#df.to_csv(output_path, index = None, header = True)

data_file = '期货结算价(活跃合约)_COMEX黄金.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '期货结算价(活跃合约)_COMEX黄金.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = '期货结算价(活跃合约)_黄金.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '期货结算价(活跃合约)_黄金.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

#data_file = '期货收盘价(活跃合约)_COMEX铜.xlsx'
#data_path = os.path.join(data_dir, data_file)
#df = pd.read_excel(data_path).dropna()
#df['指标名称'] = pd.to_datetime(df['指标名称'])
#output_file = '期货收盘价(活跃合约)_COMEX铜.csv'
#output_path = os.path.join(output_dir, output_file)
#df.to_csv(output_path, index = None, header = True)

#data_file = '期货收盘价(活跃合约)_阴极铜.xlsx'
#data_path = os.path.join(data_dir, data_file)
#df = pd.read_excel(data_path).dropna()
#df['指标名称'] = pd.to_datetime(df['指标名称'])
#output_file = '期货收盘价(活跃合约)_阴极铜.csv'
#output_path = os.path.join(output_dir, output_file)
#df.to_csv(output_path, index = None, header = True)

data_file = '期货结算价(活跃合约)_COMEX铜.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '期货结算价(活跃合约)_COMEX铜.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = '期货结算价(活跃合约)_阴极铜.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '期货结算价(活跃合约)_阴极铜.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)

data_file = '现货结算价_LME铜.xlsx'
data_path = os.path.join(data_dir, data_file)
df = pd.read_excel(data_path).dropna()
df['指标名称'] = pd.to_datetime(df['指标名称'])
output_file = '现货结算价_LME铜.csv'
output_path = os.path.join(output_dir, output_file)
df.to_csv(output_path, index = None, header = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 20
#      18 data_file = '即期汇率_美元兑人民币.xlsx'
#      19 data_path = os.path.join(data_dir, data_file)
# ---> 20 df = pd.read_excel(data_path).dropna()
#      21 df['指标名称'] = pd.to_datetime(df['指标名称'])
#      22 # 指定输出文件名
#
# AttributeError: module 'pandas' has no attribute 'read_excel'
